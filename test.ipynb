# %%
from lib.dataset import MergSet
from tqdm import tqdm
sets = MergSet([[1, 2, 3], [4, 5], [6, 7, 8, 9]])
print(f'ttl sets size: {len(sets)}')
items = []
for it in tqdm(sets):
    items.append(it)
print(items)
# Out:
# ttl sets size: 9
# 100%|██████████| 9/9 [00:00<00:00, 81005.87it/s]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
