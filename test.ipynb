# %%
from lib.spdataset import SpeechCommandsV1
train_set = SpeechCommandsV1(root_path='/root/data/speech_commands_v0.01', mode='train')
test_set = SpeechCommandsV1(root_path='/root/data/speech_commands_v0.01', mode='test')
val_set = SpeechCommandsV1(root_path='/root/data/speech_commands_v0.01', mode='validation')

print(f'train set size is:{len(train_set)}')
print(f'test set size is:{len(test_set)}')
print(f'validation set size is:{len(val_set)}')
# Out:
# train set size is:51088
# test set size is:6835
# validation set size is:6798
