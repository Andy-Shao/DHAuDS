# %%
from lib.acousticDataset import QUTNOISE
qut_noise = QUTNOISE(root_path='/home/andyshao/data/QUT-NOISE', mode='CAR', include_rate=True)
print(len(qut_noise))
# Out:
# 4

# %%
wavform, sample_rate = qut_noise[0]
print(f'wavform shape is:{wavform.shape}, sample rate is: {sample_rate}')
# Out:
# wavform shape is:torch.Size([2, 137027584]), sample rate is: 48000
