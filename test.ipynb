# %%
from lib.acousticDataset import DEMAND
demand_set = DEMAND(root_path='/root/data/DEMAND_16k', mode='DKITCHEN', include_rate=True)
print(f'sample size: {len(demand_set)}')
wavform, sample_rate = demand_set[0]
print(f'wavform shape: {wavform.shape}, sample rate: {sample_rate}')
# Out:
# sample size: 16
# wavform shape: torch.Size([1, 4800064]), sample rate: 16000
